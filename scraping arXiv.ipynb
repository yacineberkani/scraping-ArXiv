# %%
import pandas as pd
import arxiv
import requests
import os
from langdetect import detect
import spacy
topic = input("Enter the topic you need to search for : ")
nb_resultat = int(input("le nombre de resulatat :"))
search = arxiv.Search(
  query = topic,
  max_results = nb_resultat,
  sort_by = arxiv.SortCriterion.SubmittedDate,
  sort_order = arxiv.SortOrder.Descending
)
 
# Création du dossier pour stocker les PDF
folder_name = f"{topic.replace(' ', '-')}-{nb_resultat}"
os.makedirs(folder_name, exist_ok=True)
nb_articles = 0
all_data = []
for result in search.results():
    temp = ["","","","","","","",""]
    temp[0] = result.title
    temp[1] = result.authors
    temp[2] = result.published
    temp[3] = result.pdf_url
    temp[4] = result.summary
    temp[5] = result.doi
    temp[6] = result.journal_ref
    temp[7] = result.categories
    pdf_url = result.pdf_url
    if pdf_url:
        # Téléchargement du PDF
        response = requests.get(pdf_url)
        if response.status_code == 200:
            # Nom du fichier PDF
            pdf_file_name = os.path.join(folder_name, f"{result.entry_id.split('/')[-1]}.pdf")
            # Écriture du contenu dans le fichier PDF
            with open(pdf_file_name, 'wb') as f:
                f.write(response.content)
            nb_articles += 1
            print(f"Downloaded {pdf_file_name}")
            
        else:
            print(f"Failed to download PDF from {pdf_url}")
    else:
        print(f"No PDF URL available for {result.entry_id}")


    all_data.append(temp)
 
column_names = ['Title','Auture','Date','URL','Summary','DOI','Journal','Categories']
df = pd.DataFrame(all_data, columns=column_names)

print("Number of papers extracted : ",df.shape[0])
print("Number of artilces : ",nb_articles)
df
# Out:
# Enter the topic you need to search for : big data
# le nombre de resulatat :15
# /var/folders/n5/dmk8f1p11fvglwbkpkjxrnf00000gn/T/ipykernel_1276/2966120158.py:19: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():
# Downloaded big-data-15/2405.00672v1.pdf
# Downloaded big-data-15/2405.00670v1.pdf
# Downloaded big-data-15/2405.00669v1.pdf
# Downloaded big-data-15/2405.00666v1.pdf
# Downloaded big-data-15/2405.00650v1.pdf
# Downloaded big-data-15/2405.00648v1.pdf
# Downloaded big-data-15/2405.00646v1.pdf
# Downloaded big-data-15/2405.00641v1.pdf
# Downloaded big-data-15/2405.00640v1.pdf
# Downloaded big-data-15/2405.00637v1.pdf
# Downloaded big-data-15/2405.00636v1.pdf
# Downloaded big-data-15/2405.00631v1.pdf
# Downloaded big-data-15/2405.00627v1.pdf
# Downloaded big-data-15/2405.00622v1.pdf
# Downloaded big-data-15/2405.00619v1.pdf
# Number of papers extracted :  15
# Number of artilces :  15
#                                                 Title  \
# 0   TexSliders: Diffusion-Based Texture Editing in...
# 1   Adapting Pretrained Networks for Image Quality...
# 2   Euclid preparation. LensMC, weak lensing cosmi...
# 3   RGB$\leftrightarrow$X: Image decomposition and...
# 4   Grains of Saliency: Optimizing Saliency-based ...
# 5   HalluVault: A Novel Logic Programming-aided Me...
# 6   Learning to Compose: Improving Object Centric ...
# 7   Tomography of flavoured leptogenesis with prim...
# 8   Stochastic fluids with transport noise: Approx...
# 9   A Distributed Model Identification Algorithm f...
# 10  Robustness of graph embedding methods for comm...
# 11  Deep Metric Learning-Based Out-of-Distribution...
# 12  Koopman-based Deep Learning for Nonlinear Syst...
# 13               Causal Evaluation of Language Models
# 14  One-Bit Total Variation Denoising over Network...
#
#                                                Auture  \
# 0   [Julia Guerrero-Viu, Milos Hasan, Arthur Roull...
# 1   [Andrei Chubarau, Hyunjin Yoo, Tara Akhavan, J...
# 2   [Euclid Collaboration, G. Congedo, L. Miller, ...
# 3   [Zheng Zeng, Valentin Deschaintre, Iliyan Geor...
# 4       [Colton R. Crum, Samuel Webster, Adam Czajka]
# 5   [Ningke Li, Yuekang Li, Yi Liu, Ling Shi, Kail...
# 6   [Whie Jung, Jaehoon Yoo, Sungjin Ahn, Seunghoo...
# 7   [Marco Chianese, Satyabrata Datta, Rome Samant...
# 8                                   [James Woodfield]
# 9         [Vivek Khatana, Chin-Yao Chang, Wenbo Wang]
# 10  [Zhi-Feng Wei, Pablo Moriano, Ramakrishnan Kan...
# 11                               [Assefa Seyoum Wahd]
# 12           [Zexin Sun, Mingyu Chen, John Baillieul]
# 13  [Sirui Chen, Bo Peng, Meiqi Chen, Ruiqi Wang, ...
# 14      [Claire Donnat, Olga Klopp, Nicolas Verzelen]
#
#                         Date                                URL  \
# 0  2024-05-01 17:57:21+00:00  http://arxiv.org/pdf/2405.00672v1
# 1  2024-05-01 17:57:12+00:00  http://arxiv.org/pdf/2405.00670v1
# 2  2024-05-01 17:57:03+00:00  http://arxiv.org/pdf/2405.00669v1
# 3  2024-05-01 17:54:05+00:00  http://arxiv.org/pdf/2405.00666v1
# 4  2024-05-01 17:27:11+00:00  http://arxiv.org/pdf/2405.00650v1
# 5  2024-05-01 17:24:42+00:00  http://arxiv.org/pdf/2405.00648v1
# 6  2024-05-01 17:21:36+00:00  http://arxiv.org/pdf/2405.00646v1
# 7  2024-05-01 17:10:18+00:00  http://arxiv.org/pdf/2405.00641v1
# 8  2024-05-01 17:08:02+00:00  http://arxiv.org/pdf/2405.00640v1
# 9  2024-05-01 17:05:22+00:00  http://arxiv.org/pdf/2405.00637v1
# 10 2024-05-01 17:04:20+00:00  http://arxiv.org/pdf/2405.00636v1
# 11 2024-05-01 16:58:22+00:00  http://arxiv.org/pdf/2405.00631v1
# 12 2024-05-01 16:49:54+00:00  http://arxiv.org/pdf/2405.00627v1
# 13 2024-05-01 16:43:21+00:00  http://arxiv.org/pdf/2405.00622v1
# 14 2024-05-01 16:38:40+00:00  http://arxiv.org/pdf/2405.00619v1
#
#                                               Summary  \
# 0   Generative models have enabled intuitive image...
# 1   Conventional image quality metrics (IQMs), suc...
# 2   LensMC is a weak lensing shear measurement met...
# 3   The three areas of realistic forward rendering...
# 4   Incorporating human-perceptual intelligence in...
# 5   Large language models (LLMs) have transformed ...
# 6   Learning compositional representation is a key...
# 7   We explore a scenario where an early epoch of ...
# 8   We introduce and test methods for the calibrat...
# 9   In this study, we investigate agent-based appr...
# 10  This study investigates the robustness of grap...
# 11  In this paper, we present a novel approach tha...
# 12  Nonlinear differential equations are encounter...
# 13  Causal reasoning is viewed as crucial for achi...
# 14  This paper introduces a novel approach for epi...
#
#                         DOI  \
# 0   10.1145/3641519.3657444
# 1                      None
# 2                      None
# 3   10.1145/3641519.3657445
# 4                      None
# 5                      None
# 6                      None
# 7                      None
# 8                      None
# 9                      None
# 10                     None
# 11                     None
# 12                     None
# 13                     None
# 14                     None
#
#                                               Journal  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3   SIGGRAPH Conference Papers '24, July 27-August...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
#
#                                          Categories
# 0                                    [cs.GR, cs.CV]
# 1                                  [cs.CV, eess.IV]
# 2           [astro-ph.CO, physics.data-an, stat.CO]
# 3                                    [cs.CV, cs.GR]
# 4                                           [cs.CV]
# 5                                           [cs.SE]
# 6                                    [cs.CV, cs.LG]
# 7                             [hep-ph, astro-ph.CO]
# 8                [physics.flu-dyn, physics.comp-ph]
# 9                                  [eess.SY, cs.SY]
# 10  [physics.soc-ph, cs.LG, cs.SI, physics.data-an]
# 11                                          [cs.CV]
# 12                          [eess.SY, cs.LG, cs.SY]
# 13                            [cs.CL, cs.AI, cs.LG]
# 14                                        [stat.ME]

# %%
#pip install arxiv

# %%
import pandas as pd
import arxiv
import requests
import os
from langdetect import detect
from tqdm import tqdm
import spacy

# %%
def extraire_mots_cles_fr(requete):
    """
    Fonction pour extraire les mots-clés à partir de la requête de l'utilisateur en français.
    
    Arguments :
        - requete : La requête de l'utilisateur
        
    Returns :
        - mots_cles_format : Les mots-clés formatés sous forme de chaîne de caractères
    """
    nlp = spacy.load("fr_core_news_sm")
    requete_utilisateur = requete.lower()
    doc = nlp(requete_utilisateur)
    mots_cles = []
    for token in doc:
        if (token.pos_ == "NOUN" and token.dep_ not in ["ROOT","obj"]) or \
           (token.pos_ == "ADV" ) or \
           (token.pos_ == "PRON" and token.dep_ != "dep") or \
           (token.dep_ == "ROOT" and token.pos_ not in ["NOUN","VERB"]) or \
           (token.pos_ == "ADJ" ) or \
           (token.pos_ == "PROPN" and token.dep_ in ["nmod","punct"]):
            if not token.is_stop and not token.is_punct and token.text.lower() not in ['article', 'articles']:
                mots_cles.append(token.text)
    mots_cles_format = ' '.join(mots_cles)
    return mots_cles_format

def extraire_mots_cles_en(requete):
    """
    Fonction pour extraire les mots-clés à partir de la requête de l'utilisateur en anglais.
    
    Arguments :
        - requete : La requête de l'utilisateur
        
    Returns :
        - mots_cles_format : Les mots-clés formatés sous forme de chaîne de caractères
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(requete)
    mots_cles = []
    for token in doc:
        if (token.pos_ == "NOUN" ) or  (token.dep_ == "punct") or \
           (token.pos_ == "ADV") or (token.dep_ == "pobj") or \
           (token.pos_ == "PROPN" and token.dep_ != "dep") or \
           (token.pos_ == "ADJ" ) :
            if not token.is_stop and not token.is_punct and token.text.lower() not in ['article', 'articles']:
                mots_cles.append(token.text)
    mots_cles_format = ' '.join(mots_cles)
    return mots_cles_format

def detect_language(text):
    """
    Fonction pour détecter la langue d'un texte donné.
    
    Arguments :
        - text : Le texte à analyser
        
    Returns :
        - 'français' si la langue détectée est le français, sinon 'anglais'
    """
    lang = detect(text)
    if lang == 'fr':
        return 'français'
    else:
        return 'anglais'
def telecharger_articles_arxiv(sujet, nb_resultats):
    """
    Télécharge les articles d'arXiv pour un sujet donné et les stocke dans un dossier.

    Arguments :
    sujet : str - Le sujet de recherche pour les articles.
    nb_resultats : int - Le nombre de résultats à télécharger.

    Retourne :
    pandas.DataFrame - Un DataFrame contenant les détails des articles téléchargés.
    """

    
    # Effectuer la recherche sur arXiv
    recherche = arxiv.Search(
      query=sujet,
      max_results=nb_resultats,
      sort_by=arxiv.SortCriterion.SubmittedDate,
      sort_order=arxiv.SortOrder.Descending
    )
     
    # Création du dossier pour stocker les PDF
    nom_dossier = f"{sujet.replace(' ', '-')}-{nb_resultats}"
    os.makedirs(nom_dossier, exist_ok=True)

    # Initialisation du compteur d'articles téléchargés
    nb_articles = 0

    # Initialisation de la liste pour stocker toutes les données
    toutes_les_donnees = []

    # Parcourir les résultats de la recherche avec tqdm pour la barre de progression
    for resultat in tqdm(recherche.results(), desc="Téléchargement en cours"):
        # Initialisation de la liste temporaire pour stocker les données de chaque article
        temp = ["", "", "", "", "", "", "", ""]
        temp[0] = resultat.title
        temp[1] = resultat.authors
        temp[2] = resultat.published
        temp[3] = resultat.pdf_url
        temp[4] = resultat.summary
        temp[5] = resultat.doi
        temp[6] = resultat.journal_ref
        temp[7] = resultat.categories

        # Vérifier s'il existe une URL PDF pour l'article
        url_pdf = resultat.pdf_url
        if url_pdf:
            # Téléchargement du PDF
            reponse = requests.get(url_pdf)
            if reponse.status_code == 200:
                # Nom du fichier PDF
                nom_fichier_pdf = os.path.join(nom_dossier, f"{resultat.entry_id.split('/')[-1]}.pdf")
                # Écriture du contenu dans le fichier PDF
                with open(nom_fichier_pdf, 'wb') as f:
                    f.write(reponse.content)
                nb_articles += 1
                #print(f"Téléchargé {nom_fichier_pdf}")
            else:
                print(f"Échec du téléchargement du PDF depuis {url_pdf}")
        else:
            print(f"Aucune URL PDF disponible pour {resultat.entry_id}")

        # Ajouter les données de l'article à la liste des données
        toutes_les_donnees.append(temp)

    # Créer un DataFrame pandas à partir de toutes les données
    noms_colonnes = ['Titre', 'Auteur', 'Date', 'URL', 'Résumé', 'DOI', 'Journal', 'Catégories']
    df = pd.DataFrame(toutes_les_donnees, columns=noms_colonnes)
    
    # Enregistrer les données dans un fichier CSV avec le nom du dossier
    chemin_fichier_csv = os.path.join(nom_dossier, f"{nom_dossier}.csv")
    df.to_csv(chemin_fichier_csv, index=False)

    # Afficher le nombre total d'articles extraits
    #print("Nombre d'articles extraits : ", df.shape[0])

    # Afficher le nombre d'articles téléchargés
    print("Nombre d'articles téléchargés : ", nb_articles)

    # Retourner le DataFrame contenant les détails des articles téléchargés
    return print(df)

# %%
def main():
    # Demander à l'utilisateur le sujet de recherche
    requete_utilisateur = str(input("Veuillez saisir votre requête : "))

    # Détection de la langue de la requête
    langue = detect_language(requete_utilisateur)

    # Sélection de la fonction d'extraction des mots-clés en fonction de la langue détectée
    if langue == 'français':
        sujet = extraire_mots_cles_fr(requete_utilisateur)
        print("Langue détectée ==> Français")
    else:
        sujet = extraire_mots_cles_en(requete_utilisateur)
        print("Langue détectée ==> Anglais")
    # Demander à l'utilisateur le nombre de pages à parcourir
    nb_resultats = int(input("Entrez le nombre de résultats : "))
    telecharger_articles_arxiv(sujet, nb_resultats)
if __name__ == "__main__":
    main()
# Out:
# Veuillez saisir votre requête : je cherches articles sur Chat GPT4
# Langue détectée ==> Français
# Entrez le nombre de résultats : 22
# /var/folders/n5/dmk8f1p11fvglwbkpkjxrnf00000gn/T/ipykernel_6406/4076291642.py:97: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for resultat in tqdm(recherche.results(), desc="Téléchargement en cours"):
# Téléchargement en cours: 22it [00:11,  1.89it/s]
# Nombre d'articles téléchargés :  22
#                                                 Titre  \
# 0   Google or ChatGPT: Who is the Better Helper fo...
# 1   Integrating A.I. in Higher Education: Protocol...
# 2   Social Life Simulation for Non-Cognitive Skill...
# 3         Iterative Reasoning Preference Optimization
# 4   Enhancing GUI Exploration Coverage of Android ...
# 5   Replacing Judges with Juries: Evaluating LLM G...
# 6      PECC: Problem Extraction and Coding Challenges
# 7   Injecting Salesperson's Dialogue Strategies in...
# 8   Ethical Reasoning and Moral Value Alignment of...
# 9   Mixture-of-Instructions: Comprehensive Alignme...
# 10  Large Language Models Perform on Par with Expe...
# 11  MMT-Bench: A Comprehensive Multimodal Benchmar...
# 12  Automated Multi-Language to English Machine Tr...
# 13  Phi-3 Technical Report: A Highly Capable Langu...
# 14  Beyond Accuracy: Investigating Error Types in ...
# 15  Groma: Localized Visual Tokenization for Groun...
# 16  Can LLMs Understand Computer Networks? Towards...
# 17  Reka Core, Flash, and Edge: A Series of Powerf...
# 18  Introducing v0.5 of the AI Safety Benchmark fr...
# 19  Inductive-Deductive Strategy Reuse for Multi-T...
# 20  Forcing Diffuse Distributions out of Language ...
# 21        Self-Supervised Visual Preference Alignment
#
#                                                Auteur  \
# 0                     [Mengmeng Zhang, Xiantong Yang]
# 1   [Syed Hasib Akhter Faruqui, Nazia Tasnim, Ifte...
# 2               [Zihan Yan, Yaohong Xiang, Yun Huang]
# 3   [Richard Yuanzhe Pang, Weizhe Yuan, Kyunghyun ...
# 4   [Han Hu, Han Wang, Ruiqi Dong, Xiao Chen, Chun...
# 5   [Pat Verga, Sebastian Hofstatter, Sophia Altha...
# 6           [Patrick Haller, Jonas Golde, Alan Akbik]
# 7                       [Wen-Yu Chang, Yun-Nung Chen]
# 8   [Utkarsh Agarwal, Kumar Tanmay, Aditi Khandelw...
# 9             [Bowen Xu, Shaoyu Wu, Kai Liu, Lulu Hu]
# 10  [Isabelle Lorge, Dan W. Joyce, Andrey Kormilit...
# 11  [Kaining Ying, Fanqing Meng, Jin Wang, Zhiqian...
# 12  [Elijah Pelofske, Vincent Urias, Lorie M. Lieb...
# 13  [Marah Abdin, Sam Ade Jacobs, Ammar Ahmad Awan...
# 14  [Soumyadeep Roy, Aparup Khatua, Fatemeh Ghooch...
# 15  [Chuofan Ma, Yi Jiang, Jiannan Wu, Zehuan Yuan...
# 16  [Denis Donadel, Francesco Marchiori, Luca Pajo...
# 17  [Aitor Ormazabal, Che Zheng, Cyprien de Masson...
# 18  [Bertie Vidgen, Adarsh Agrawal, Ahmed M. Ahmed...
# 19  [Jiao Ou, Jiayu Wu, Che Liu, Fuzheng Zhang, Di...
# 20  [Yiming Zhang, Avi Schwarzschild, Nicholas Car...
# 21      [Ke Zhu, Liang Zhao, Zheng Ge, Xiangyu Zhang]
#
#                         Date                                URL  \
# 0  2024-05-01 06:28:58+00:00  http://arxiv.org/pdf/2405.00341v1
# 1  2024-05-01 05:39:07+00:00  http://arxiv.org/pdf/2405.00330v1
# 2  2024-05-01 01:45:50+00:00  http://arxiv.org/pdf/2405.00273v1
# 3  2024-04-30 17:28:05+00:00  http://arxiv.org/pdf/2404.19733v1
# 4  2024-04-30 07:24:32+00:00  http://arxiv.org/pdf/2404.19307v1
# 5  2024-04-29 15:33:23+00:00  http://arxiv.org/pdf/2404.18796v2
# 6  2024-04-29 15:02:14+00:00  http://arxiv.org/pdf/2404.18766v1
# 7  2024-04-29 10:12:04+00:00  http://arxiv.org/pdf/2404.18564v1
# 8  2024-04-29 06:42:27+00:00  http://arxiv.org/pdf/2404.18460v1
# 9  2024-04-29 03:58:12+00:00  http://arxiv.org/pdf/2404.18410v1
# 10 2024-04-25 09:42:50+00:00  http://arxiv.org/pdf/2404.16461v2
# 11 2024-04-24 17:37:05+00:00  http://arxiv.org/pdf/2404.16006v1
# 12 2024-04-23 02:19:35+00:00  http://arxiv.org/pdf/2404.14680v1
# 13 2024-04-22 14:32:33+00:00  http://arxiv.org/pdf/2404.14219v2
# 14 2024-04-20 07:29:06+00:00  http://arxiv.org/pdf/2404.13307v1
# 15 2024-04-19 17:22:51+00:00  http://arxiv.org/pdf/2404.13013v1
# 16 2024-04-19 07:41:54+00:00  http://arxiv.org/pdf/2404.12689v1
# 17 2024-04-18 17:59:48+00:00  http://arxiv.org/pdf/2404.12387v1
# 18 2024-04-18 15:01:00+00:00  http://arxiv.org/pdf/2404.12241v1
# 19 2024-04-17 06:26:32+00:00  http://arxiv.org/pdf/2404.11095v1
# 20 2024-04-16 19:17:23+00:00  http://arxiv.org/pdf/2404.10859v1
# 21 2024-04-16 12:19:54+00:00  http://arxiv.org/pdf/2404.10501v1
#
#                                                Résumé  \
# 0   Using information technology tools for academi...
# 1   Learning never ends, and there is no age limit...
# 2   Non-cognitive skills are crucial for personal ...
# 3   Iterative preference optimization methods have...
# 4   Mobile apps are ubiquitous in our daily lives ...
# 5   As Large Language Models (LLMs) have become mo...
# 6   Recent advancements in large language models (...
# 7   Recent research in dialogue systems and corpor...
# 8   Ethical reasoning is a crucial skill for Large...
# 9   With the proliferation of large language model...
# 10  Mental health in children and adolescents has ...
# 11  Large Vision-Language Models (LVLMs) show sign...
# 12  The task of accurate and efficient language tr...
# 13  We introduce phi-3-mini, a 3.8 billion paramet...
# 14  GPT-4 demonstrates high accuracy in medical QA...
# 15  We introduce Groma, a Multimodal Large Languag...
# 16  Recent advancements in Artificial Intelligence...
# 17  We introduce Reka Core, Flash, and Edge, a ser...
# 18  This paper introduces v0.5 of the AI Safety Be...
# 19  Aligning large language models (LLMs) with hum...
# 20  Despite being trained specifically to follow u...
# 21  This paper makes the first attempt towards uns...
#
#                         DOI Journal  \
# 0                      None    None
# 1                      None    None
# 2                      None    None
# 3                      None    None
# 4                      None    None
# 5                      None    None
# 6                      None    None
# 7                      None    None
# 8                      None    None
# 9                      None    None
# 10                     None    None
# 11                     None    None
# 12                     None    None
# 13                     None    None
# 14  10.1145/3626772.3657882    None
# 15                     None    None
# 16                     None    None
# 17                     None    None
# 18                     None    None
# 19                     None    None
# 20                     None    None
# 21                     None    None
#
#                                     Catégories
# 0                                      [cs.HC]
# 1                               [cs.CY, cs.AI]
# 2                               [cs.CL, cs.HC]
# 3                               [cs.CL, cs.AI]
# 4                               [cs.SE, cs.CR]
# 5                               [cs.CL, cs.AI]
# 6                                      [cs.AI]
# 7                               [cs.CL, cs.AI]
# 8                               [cs.CL, cs.AI]
# 9                                      [cs.CL]
# 10                                     [cs.CL]
# 11                                     [cs.CV]
# 12                       [cs.CL, cs.AI, cs.LG]
# 13                              [cs.CL, cs.AI]
# 14                                     [cs.CL]
# 15                [cs.CV, cs.AI, cs.CL, cs.LG]
# 16  [cs.NI, cs.AI, cs.ET, C.2.1; C.2.5; I.2.1]
# 17                              [cs.CL, cs.CV]
# 18                              [cs.CL, cs.AI]
# 19                              [cs.CL, cs.AI]
# 20                              [cs.CL, cs.LG]
# 21                [cs.CV, cs.AI, cs.CL, cs.LG]

# %%
pd.read_csv('Chat-GPT4-22/Chat-GPT4-22.csv')
# Out:
#                                                 Titre  \
# 0   Google or ChatGPT: Who is the Better Helper fo...
# 1   Integrating A.I. in Higher Education: Protocol...
# 2   Social Life Simulation for Non-Cognitive Skill...
# 3         Iterative Reasoning Preference Optimization
# 4   Enhancing GUI Exploration Coverage of Android ...
# 5   Replacing Judges with Juries: Evaluating LLM G...
# 6      PECC: Problem Extraction and Coding Challenges
# 7   Injecting Salesperson's Dialogue Strategies in...
# 8   Ethical Reasoning and Moral Value Alignment of...
# 9   Mixture-of-Instructions: Comprehensive Alignme...
# 10  Large Language Models Perform on Par with Expe...
# 11  MMT-Bench: A Comprehensive Multimodal Benchmar...
# 12  Automated Multi-Language to English Machine Tr...
# 13  Phi-3 Technical Report: A Highly Capable Langu...
# 14  Beyond Accuracy: Investigating Error Types in ...
# 15  Groma: Localized Visual Tokenization for Groun...
# 16  Can LLMs Understand Computer Networks? Towards...
# 17  Reka Core, Flash, and Edge: A Series of Powerf...
# 18  Introducing v0.5 of the AI Safety Benchmark fr...
# 19  Inductive-Deductive Strategy Reuse for Multi-T...
# 20  Forcing Diffuse Distributions out of Language ...
# 21        Self-Supervised Visual Preference Alignment
#
#                                                Auteur  \
# 0   [arxiv.Result.Author('Mengmeng Zhang'), arxiv....
# 1   [arxiv.Result.Author('Syed Hasib Akhter Faruqu...
# 2   [arxiv.Result.Author('Zihan Yan'), arxiv.Resul...
# 3   [arxiv.Result.Author('Richard Yuanzhe Pang'), ...
# 4   [arxiv.Result.Author('Han Hu'), arxiv.Result.A...
# 5   [arxiv.Result.Author('Pat Verga'), arxiv.Resul...
# 6   [arxiv.Result.Author('Patrick Haller'), arxiv....
# 7   [arxiv.Result.Author('Wen-Yu Chang'), arxiv.Re...
# 8   [arxiv.Result.Author('Utkarsh Agarwal'), arxiv...
# 9   [arxiv.Result.Author('Bowen Xu'), arxiv.Result...
# 10  [arxiv.Result.Author('Isabelle Lorge'), arxiv....
# 11  [arxiv.Result.Author('Kaining Ying'), arxiv.Re...
# 12  [arxiv.Result.Author('Elijah Pelofske'), arxiv...
# 13  [arxiv.Result.Author('Marah Abdin'), arxiv.Res...
# 14  [arxiv.Result.Author('Soumyadeep Roy'), arxiv....
# 15  [arxiv.Result.Author('Chuofan Ma'), arxiv.Resu...
# 16  [arxiv.Result.Author('Denis Donadel'), arxiv.R...
# 17  [arxiv.Result.Author('Aitor Ormazabal'), arxiv...
# 18  [arxiv.Result.Author('Bertie Vidgen'), arxiv.R...
# 19  [arxiv.Result.Author('Jiao Ou'), arxiv.Result....
# 20  [arxiv.Result.Author('Yiming Zhang'), arxiv.Re...
# 21  [arxiv.Result.Author('Ke Zhu'), arxiv.Result.A...
#
#                          Date                                URL  \
# 0   2024-05-01 06:28:58+00:00  http://arxiv.org/pdf/2405.00341v1
# 1   2024-05-01 05:39:07+00:00  http://arxiv.org/pdf/2405.00330v1
# 2   2024-05-01 01:45:50+00:00  http://arxiv.org/pdf/2405.00273v1
# 3   2024-04-30 17:28:05+00:00  http://arxiv.org/pdf/2404.19733v1
# 4   2024-04-30 07:24:32+00:00  http://arxiv.org/pdf/2404.19307v1
# 5   2024-04-29 15:33:23+00:00  http://arxiv.org/pdf/2404.18796v2
# 6   2024-04-29 15:02:14+00:00  http://arxiv.org/pdf/2404.18766v1
# 7   2024-04-29 10:12:04+00:00  http://arxiv.org/pdf/2404.18564v1
# 8   2024-04-29 06:42:27+00:00  http://arxiv.org/pdf/2404.18460v1
# 9   2024-04-29 03:58:12+00:00  http://arxiv.org/pdf/2404.18410v1
# 10  2024-04-25 09:42:50+00:00  http://arxiv.org/pdf/2404.16461v2
# 11  2024-04-24 17:37:05+00:00  http://arxiv.org/pdf/2404.16006v1
# 12  2024-04-23 02:19:35+00:00  http://arxiv.org/pdf/2404.14680v1
# 13  2024-04-22 14:32:33+00:00  http://arxiv.org/pdf/2404.14219v2
# 14  2024-04-20 07:29:06+00:00  http://arxiv.org/pdf/2404.13307v1
# 15  2024-04-19 17:22:51+00:00  http://arxiv.org/pdf/2404.13013v1
# 16  2024-04-19 07:41:54+00:00  http://arxiv.org/pdf/2404.12689v1
# 17  2024-04-18 17:59:48+00:00  http://arxiv.org/pdf/2404.12387v1
# 18  2024-04-18 15:01:00+00:00  http://arxiv.org/pdf/2404.12241v1
# 19  2024-04-17 06:26:32+00:00  http://arxiv.org/pdf/2404.11095v1
# 20  2024-04-16 19:17:23+00:00  http://arxiv.org/pdf/2404.10859v1
# 21  2024-04-16 12:19:54+00:00  http://arxiv.org/pdf/2404.10501v1
#
#                                                Résumé  \
# 0   Using information technology tools for academi...
# 1   Learning never ends, and there is no age limit...
# 2   Non-cognitive skills are crucial for personal ...
# 3   Iterative preference optimization methods have...
# 4   Mobile apps are ubiquitous in our daily lives ...
# 5   As Large Language Models (LLMs) have become mo...
# 6   Recent advancements in large language models (...
# 7   Recent research in dialogue systems and corpor...
# 8   Ethical reasoning is a crucial skill for Large...
# 9   With the proliferation of large language model...
# 10  Mental health in children and adolescents has ...
# 11  Large Vision-Language Models (LVLMs) show sign...
# 12  The task of accurate and efficient language tr...
# 13  We introduce phi-3-mini, a 3.8 billion paramet...
# 14  GPT-4 demonstrates high accuracy in medical QA...
# 15  We introduce Groma, a Multimodal Large Languag...
# 16  Recent advancements in Artificial Intelligence...
# 17  We introduce Reka Core, Flash, and Edge, a ser...
# 18  This paper introduces v0.5 of the AI Safety Be...
# 19  Aligning large language models (LLMs) with hum...
# 20  Despite being trained specifically to follow u...
# 21  This paper makes the first attempt towards uns...
#
#                         DOI  Journal  \
# 0                       NaN      NaN
# 1                       NaN      NaN
# 2                       NaN      NaN
# 3                       NaN      NaN
# 4                       NaN      NaN
# 5                       NaN      NaN
# 6                       NaN      NaN
# 7                       NaN      NaN
# 8                       NaN      NaN
# 9                       NaN      NaN
# 10                      NaN      NaN
# 11                      NaN      NaN
# 12                      NaN      NaN
# 13                      NaN      NaN
# 14  10.1145/3626772.3657882      NaN
# 15                      NaN      NaN
# 16                      NaN      NaN
# 17                      NaN      NaN
# 18                      NaN      NaN
# 19                      NaN      NaN
# 20                      NaN      NaN
# 21                      NaN      NaN
#
#                                            Catégories
# 0                                           ['cs.HC']
# 1                                  ['cs.CY', 'cs.AI']
# 2                                  ['cs.CL', 'cs.HC']
# 3                                  ['cs.CL', 'cs.AI']
# 4                                  ['cs.SE', 'cs.CR']
# 5                                  ['cs.CL', 'cs.AI']
# 6                                           ['cs.AI']
# 7                                  ['cs.CL', 'cs.AI']
# 8                                  ['cs.CL', 'cs.AI']
# 9                                           ['cs.CL']
# 10                                          ['cs.CL']
# 11                                          ['cs.CV']
# 12                        ['cs.CL', 'cs.AI', 'cs.LG']
# 13                                 ['cs.CL', 'cs.AI']
# 14                                          ['cs.CL']
# 15               ['cs.CV', 'cs.AI', 'cs.CL', 'cs.LG']
# 16  ['cs.NI', 'cs.AI', 'cs.ET', 'C.2.1; C.2.5; I.2...
# 17                                 ['cs.CL', 'cs.CV']
# 18                                 ['cs.CL', 'cs.AI']
# 19                                 ['cs.CL', 'cs.AI']
# 20                                 ['cs.CL', 'cs.LG']
# 21               ['cs.CV', 'cs.AI', 'cs.CL', 'cs.LG']
